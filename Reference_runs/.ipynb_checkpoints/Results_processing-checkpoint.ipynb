# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import re

# %%
def move_column_inplace(df, col, pos):
    col = df.pop(col)
    df.insert(pos, col.name, col)

def process_output(path = ''):
    '''Takes in the path to the folder with the data
    and returns a dataframe with the benchmark results in the columns 
    with their corresponding number of nodes and processes per node'''
    all_files = glob.glob(path + "*.log")

    df = pd.read_csv('data_23_32_1.log', index_col=None, skipinitialspace = True, skiprows = 322, sep = ':')
    df2 = df.transpose()
    df2.reset_index(level=0, inplace=True)
    df2 = df2.rename(columns=df2.iloc[0])
    df2.drop([0,1], inplace = True)

    for filename in all_files:
        df = pd.read_csv(filename, index_col=None, skipinitialspace = True, skiprows = 322, sep = ':')
        df = df.transpose()
        df.reset_index(level=0, inplace=True)
        df = df.rename(columns=df.iloc[0])
        df.drop([0], inplace = True)
        temp = [int(s) for s in re.findall(r'\d+', filename)]
        #df.insert(1, 'Number of nodes', [temp[1]])
        #df.insert(2, 'Processes/Node', [temp[2]])
        df['Number of nodes'] = temp[1]
        df['Processes/Node'] = temp[2]
        df2 = df2.append(df)

    df2.reset_index(drop=True, inplace=True)
    move_column_inplace(df2, 'Number of nodes', 1)
    move_column_inplace(df2, 'Processes/Node', 2)
    return df2

# %%
df = process_output()

# %%
df
# Out:
#    SCALE  Number of nodes  Processes/Node edgefactor NBFS graph_generation  \
# 0     26             32.0            32.0         16   64          6.69615
# 1     23              1.0            32.0         16   64          6.09462
# 2     24              1.0            32.0         16   64          6.29188
# 3     25             32.0            32.0         16   64          6.50194
# 4     23             32.0             1.0         16   64          6.09271
# 5     26             32.0             1.0         16   64          26.6417
# 6     25             32.0             1.0         16   64          12.9391
# 7     24             32.0             1.0         16   64           6.2828
# 8     24             32.0            32.0         16   64          6.32468
# 9     25              1.0            32.0         16   64          13.0153
# 10    23             32.0            32.0         16   64          6.12063
#
#    num_mpi_processes construction_time bfs  min_time bfs  firstquartile_time  \
# 0               1024           1.10703      0.208882                0.215516
# 1                 32           1.41006      0.409903                0.414988
# 2                 32             1.986        0.8161                0.822134
# 3               1024          0.951171      0.114364                0.117605
# 4                 32          0.815469      0.262032                0.264642
# 5                 32           4.69107       2.13863                 2.16052
# 6                 32           2.65507       1.10746                 1.11422
# 7                 32           1.05329      0.513187                 0.51795
# 8               1024           0.89631     0.0621875               0.0642077
# 9                 32           4.25838       1.60771                 1.63171
# 10              1024           0.78248     0.0345092               0.0361481
#
#     ... bfs  max_TEPS bfs  harmonic_mean_TEPS bfs  harmonic_stddev_TEPS  \
# 0   ...   5.14035e+09          !  4.88064e+09               1.74538e+07
# 1   ...   3.27428e+08          !  3.18343e+08                    780263
# 2   ...   3.28918e+08          !  3.22433e+08                    582940
# 3   ...   4.69432e+09          !  4.48042e+09               1.73311e+07
# 4   ...   5.12204e+08          !  5.01218e+08                    899250
# 5   ...   5.02064e+08          !  4.92652e+08                    655001
# 6   ...    4.8477e+08          !  4.76001e+08                    760170
# 7   ...   5.23064e+08          !  5.12737e+08                    911825
# 8   ...   4.31645e+09          !  4.08328e+09               1.75854e+07
# 9   ...    3.3393e+08          !  3.26208e+08                    456740
# 10  ...   3.88922e+09          !  3.61827e+09               1.67808e+07
#
#    bfs  min_validate bfs  firstquartile_validate bfs  median_validate  \
# 0           0.549104                    0.555494             0.558304
# 1            1.27079                      1.2764              1.28104
# 2            2.67585                     2.68479              2.69282
# 3           0.279938                    0.283846              0.28573
# 4           0.653587                    0.656729             0.659699
# 5             5.9433                     5.95969               5.9771
# 6            2.93726                     2.94705              2.95141
# 7            1.34079                     1.34561                1.351
# 8           0.145558                    0.147812              0.14941
# 9            5.54108                      5.5606              5.57425
# 10         0.0827462                   0.0843475            0.0859615
#
#    bfs  thirdquartile_validate bfs  max_validate bfs  mean_validate  \
# 0                     0.562302          0.571503           0.559254
# 1                      1.28812           1.30218            1.28257
# 2                      2.70009           2.73528            2.69444
# 3                     0.287481          0.296369           0.285967
# 4                     0.663122          0.673304            0.66039
# 5                      5.99464            6.0165            5.97757
# 6                        2.958           2.97216            2.95269
# 7                      1.35526           1.36438            1.35125
# 8                     0.151729          0.161068           0.149815
# 9                      5.58436           5.65657            5.57561
# 10                   0.0866651         0.0913587          0.0858191
#
#    bfs  stddev_validate
# 0            0.00513258
# 1            0.00754217
# 2             0.0116392
# 3            0.00306944
# 4            0.00453292
# 5             0.0202333
# 6            0.00797395
# 7            0.00632809
# 8            0.00277935
# 9             0.0228066
# 10           0.00167238
#
# [11 rows x 36 columns]

# %%
df2
# Out:
#    SCALE edgefactor NBFS graph_generation num_mpi_processes construction_time  \
# 0     26         16   64          6.69615              1024           1.10703
# 1     23         16   64          6.09462                32           1.41006
# 2     24         16   64          6.29188                32             1.986
# 3     25         16   64          6.50194              1024          0.951171
# 4     23         16   64          6.09271                32          0.815469
# 5     26         16   64          26.6417                32           4.69107
# 6     25         16   64          12.9391                32           2.65507
# 7     24         16   64           6.2828                32           1.05329
# 8     24         16   64          6.32468              1024           0.89631
# 9     25         16   64          13.0153                32           4.25838
# 10    23         16   64          6.12063              1024           0.78248
#
#    bfs  min_time bfs  firstquartile_time bfs  median_time  \
# 0       0.208882                0.215516         0.218762
# 1       0.409903                0.414988         0.420755
# 2         0.8161                0.822134         0.830775
# 3       0.114364                0.117605         0.119312
# 4       0.262032                0.264642         0.266497
# 5        2.13863                 2.16052          2.17217
# 6        1.10746                 1.11422          1.12834
# 7       0.513187                 0.51795         0.522089
# 8      0.0621875               0.0642077        0.0653661
# 9        1.60771                 1.63171          1.64782
# 10     0.0345092               0.0361481        0.0368034
#
#    bfs  thirdquartile_time  ... bfs  harmonic_stddev_TEPS bfs  min_validate  \
# 0                 0.223237  ...               1.74538e+07          0.549104
# 1                 0.428303  ...                    780263           1.27079
# 2                  0.84171  ...                    582940           2.67585
# 3                  0.12172  ...               1.73311e+07          0.279938
# 4                 0.271089  ...                    899250          0.653587
# 5                  2.19975  ...                    655001            5.9433
# 6                   1.1398  ...                    760170           2.93726
# 7                 0.527501  ...                    911825           1.34079
# 8                0.0670414  ...               1.75854e+07          0.145558
# 9                  1.65911  ...                    456740           5.54108
# 10               0.0381267  ...               1.67808e+07         0.0827462
#
#    bfs  firstquartile_validate bfs  median_validate  \
# 0                     0.555494             0.558304
# 1                       1.2764              1.28104
# 2                      2.68479              2.69282
# 3                     0.283846              0.28573
# 4                     0.656729             0.659699
# 5                      5.95969               5.9771
# 6                      2.94705              2.95141
# 7                      1.34561                1.351
# 8                     0.147812              0.14941
# 9                       5.5606              5.57425
# 10                   0.0843475            0.0859615
#
#    bfs  thirdquartile_validate bfs  max_validate bfs  mean_validate  \
# 0                     0.562302          0.571503           0.559254
# 1                      1.28812           1.30218            1.28257
# 2                      2.70009           2.73528            2.69444
# 3                     0.287481          0.296369           0.285967
# 4                     0.663122          0.673304            0.66039
# 5                      5.99464            6.0165            5.97757
# 6                        2.958           2.97216            2.95269
# 7                      1.35526           1.36438            1.35125
# 8                     0.151729          0.161068           0.149815
# 9                      5.58436           5.65657            5.57561
# 10                   0.0866651         0.0913587          0.0858191
#
#    bfs  stddev_validate Number of nodes Processes/Node
# 0            0.00513258            32.0           32.0
# 1            0.00754217             1.0           32.0
# 2             0.0116392             1.0           32.0
# 3            0.00306944            32.0           32.0
# 4            0.00453292            32.0            1.0
# 5             0.0202333            32.0            1.0
# 6            0.00797395            32.0            1.0
# 7            0.00632809            32.0            1.0
# 8            0.00277935            32.0           32.0
# 9             0.0228066             1.0           32.0
# 10           0.00167238            32.0           32.0
#
# [11 rows x 36 columns]
